# %% [markdown]
# # Recent graduate data visualization by majors
# We'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregates the data. FiveThirtyEight cleaned the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/tree/master/college-majors).

# %% [markdown]
# Using visualizations, we can start to explore questions from the dataset like:
#
# - Do students in more popular majors make more money?
#
#     - Using scatter plots
#
# - How many majors are predominantly male? Predominantly female?
#
#     - Using histograms
#
# - Which category of majors have the most students?
#
#     - Using bar plots
#
# We'll explore how to do these and more while primarily working in pandas. Before we start creating data visualizations, let's import the libraries we need and remove rows containing null values.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

recent_grads = pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head(2)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
#
#   Major_category  ShareWomen  Sample_size  Employed  ...  Part_time  \
# 0    Engineering    0.120564           36      1976  ...        270
# 1    Engineering    0.101852            7       640  ...        170
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
# 1           350               257             50
#
# [2 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads=recent_grads.dropna() #Drop rows with missing values

# %%
cleaned_data_count = recent_grads.shape[0]
deleted_data_count = raw_data_count - cleaned_data_count
print(deleted_data_count)
# Out:
# 1

# %% [markdown]
# This shows us there is 1 data with missing values. So, we will start visualize with cleaned data.
#
# ## Scatter Plot

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Employed vs. Median')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Employed vs. Unemployment_rate')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Full_time vs. Median')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='ShareWomen vs. Unemployment_rate')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Men vs. Median')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Women vs. Median')

# %% [markdown]
# - Do students in more popular majors make more money?
# - Do students that majored in subjects that were majority female make more money?
# - Is there any link between the number of full-time employees and median salary?
#
# From the scatter plots, it is hard to find out the answer for questions above since there is no relationship found from those plots. So, we will go over to histogram to explore each columns

# %% [markdown]
# ## Histogram

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))

for r in range(0,4):
    ax = fig.add_subplot(4,1,r+1)
    ax = recent_grads[cols[r]].plot(kind='hist', title=cols[r], rot=30)
    
fig.subplots_adjust(hspace=.4)

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))

for r in range(4,8):
    ax = fig.add_subplot(4,1,r-3)
    ax = recent_grads[cols[r]].plot(kind='hist', title=cols[r], rot=30)
    
fig.subplots_adjust(hspace=.4)

# %% [markdown]
# From the histogram, most common median salary is found to be between \$30,000 to \$40,000.

# %% [markdown]
# ## Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000181F6982D00>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000181F6C3BCD0>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Major_code", "Men"]], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000181F5450070>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar Plot

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)
category_sorted_list = recent_grads["Major_category"].value_counts(normalize=True)
#Creating dataframe for top ten major categories with highest total number of students
top_ten_major_category = category_sorted_list.head(10).index

category_totals={}
for category in top_ten_major_category:
    category_only = recent_grads[recent_grads["Major_category"]==category]
    category_total = category_only["Total"].sum()
    category_totals[category]=category_total

mct_series = pd.Series(category_totals)
mct_df = pd.DataFrame(mct_series, columns=["Total"])
mct_df= mct_df.sort_values("Total", ascending=False) 

mct_df.plot.bar(legend=False)

# %% [markdown]
# From first ten rows bar plot, we can see that sharewomen values are low at many engineerings except for astronomy and astrophysics  and actuarial engineering.
# From the top ten major category graph at the bottom, we can see that Business has most students following by Humanities & Liberal Arts, and Education.
